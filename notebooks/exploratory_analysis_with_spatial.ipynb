# %% [markdown]
# # Exploratory Data Analysis
#
# Updated: 11/2/25
#
# ## Purpose
#
# This notebook is used to explore and comment on the quality of the data collected as part of the 10/26/25 Context Report. We will explore and analyze each of the datasets collected individually, and we will look to combine them in some meaningful way.

# %% [markdown]
# ### Read in Data

# %%
import pandas as pd
import numpy as np

well_owners = pd.read_excel('../data/well_owners_list.xls')

quarters_2020 = pd.read_excel('../data/quarterly/2020_AllQtrs_FINAL_11172022.xlsx')
quarters_2021 = pd.read_excel('../data/quarterly/2021_AllQtrs_FINAL_11172022.xlsx')
quarters_2022 = pd.read_excel('../data/quarterly/2022_AllQtrs_FINAL_03032023.xlsx')
quarters_2023 = pd.read_excel('../data/quarterly/2023_AllQtrs_FINAL_05312024.xlsx')
quarters_2024 = pd.read_excel('../data/quarterly/2024_AllQtrs.xlsx')
quarters_2025 = pd.read_excel('../data/quarterly/2025_AllQtrs_FINAL_08202025.xlsx')

annual_2010 = pd.read_excel('../data/annual/Combined Production 2010.xlsx')
annual_2011 = pd.read_excel('../data/annual/Combined Production 2011.xlsx')
annual_2012 = pd.read_excel('../data/annual/Combined Production 2012.xlsx')
annual_2013 = pd.read_excel('../data/annual/Combined Production 2013.xlsx')
annual_2014 = pd.read_excel('../data/annual/Combined Production 2014.xlsx')
annual_2015 = pd.read_excel('../data/annual/Combined Production 2015.xlsx')
annual_2016 = pd.read_excel('../data/annual/Combined Production 2016.xlsx')
annual_2017 = pd.read_excel('../data/annual/Combined Production 2017.xlsx')
annual_2018 = pd.read_excel('../data/annual/2018_Horizontal_and_Vertical_Production_08292022.xlsx')
annual_2019 = pd.read_excel('../data/annual/2019_Horizontal_and_Vertical_Production_11172022.xlsx')
annual_2020 = pd.read_excel('../data/annual/2020_Horizontal_and_Vertical_Production_11172022.xlsx')
annual_2021 = pd.read_excel('../data/annual/2021_Horizontal_and_Vertical_Production_03202024.xlsx')
annual_2022 = pd.read_excel('../data/annual/2022_Horizontal_and_Vertical_Production_1228223.xlsx')
annual_2023 = pd.read_excel('../data/annual/2023_Horizontal_and_Vertical_Production_07022025.xlsx')
annual_2024 = pd.read_excel('../data/annual/2024_Horizontal_and_Vertical_Production_07022025.xlsx')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# c:\Users\willf\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %% [markdown]
# ### Quarterly Production
#
# We want to combine the quarterly production files into one dataset.

# %%
# Ensure the columns are consistent across all quarterly dataframes
quarterly_dfs = [quarters_2020, quarters_2021, quarters_2022, quarters_2023, quarters_2024, quarters_2025]
for i in range(1, len(quarterly_dfs)):
    for j in range(1, i):
        if not quarterly_dfs[i].columns.equals(quarterly_dfs[j].columns):
            print(f"Columns for quarterly dataframe {i} do not match the quarterly dataframe {j}.")

# The columns don't match, let's see why
for i in range(len(quarterly_dfs)):
    print(f"Quarterly dataframe {i} columns: {quarterly_dfs[i].columns.tolist()}")

# For 2020-2022, we need to change 'Quarter' to 'Quarter (1, 2, 3, 4, n/a)' and change 'Days' to 'Days in Production'
quarters_2020 = quarters_2020.rename(columns={'Quarter': 'Quarter (1, 2, 3, 4, n/a)', 'Days': 'Days in Production'})
quarters_2021 = quarters_2021.rename(columns={'Quarter': 'Quarter (1, 2, 3, 4, n/a)', 'Days': 'Days in Production'})
quarters_2022 = quarters_2022.rename(columns={'Quarter': 'Quarter (1, 2, 3, 4, n/a)', 'Days': 'Days in Production'})

# Recheck columns
quarterly_dfs = [quarters_2020, quarters_2021, quarters_2022, quarters_2023, quarters_2024, quarters_2025]
for i in range(1, len(quarterly_dfs)):
    for j in range(1, i):
        if not quarterly_dfs[i].columns.equals(quarterly_dfs[j].columns):
            print(f"Columns for quarterly dataframe {i} do not match the quarterly dataframe {j}.")
# Out:
# Columns for quarterly dataframe 3 do not match the quarterly dataframe 1.
# Columns for quarterly dataframe 3 do not match the quarterly dataframe 2.
# Columns for quarterly dataframe 4 do not match the quarterly dataframe 1.
# Columns for quarterly dataframe 4 do not match the quarterly dataframe 2.
# Columns for quarterly dataframe 5 do not match the quarterly dataframe 1.
# Columns for quarterly dataframe 5 do not match the quarterly dataframe 2.
# Quarterly dataframe 0 columns: ['API Number', 'Production Year', 'Quarter', 'Owner Name', 'County', 'Township', 'Well Name and Number', 'Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days', 'Date of First Production']
# Quarterly dataframe 1 columns: ['API Number', 'Production Year', 'Quarter', 'Owner Name', 'County', 'Township', 'Well Name and Number', 'Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days', 'Date of First Production']
# Quarterly dataframe 2 columns: ['API Number', 'Production Year', 'Quarter', 'Owner Name', 'County', 'Township', 'Well Name and Number', 'Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days', 'Date of First Production']
# Quarterly dataframe 3 columns: ['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)', 'Owner Name', 'County', 'Township', 'Well Name and Number', 'Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days in Production', 'Date of First Production']
# Quarterly dataframe 4 columns: ['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)', 'Owner Name', 'County', 'Township', 'Well Name and Number', 'Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days in Production', 'Date of First Production']
# Quarterly dataframe 5 columns: ['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)', 'Owner Name', 'County', 'Township', 'Well Name and Number', 'Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days in Production', 'Date of First Production']

# %%
# Concatenate all quarterly dataframes
quarterly_production = pd.concat(quarterly_dfs, ignore_index=True)
display(quarterly_production.head(5))
print(quarterly_production.shape)
print(quarterly_production.dtypes)
# Out:
#        API Number  Production Year  Quarter (1, 2, 3, 4, n/a)  \
# 0  34013209230000             2020                          1
# 1  34059242520100             2020                          1
# 2  34059242530000             2020                          1
# 3  34059242540000             2020                          1
# 4  34059242550000             2020                          1
#
#                       Owner Name    County  Township   Well Name and Number  \
# 0  ANTERO RESOURCES  CORPORATION   BELMONT  KIRKWOOD  HORSESHOE UNIT     1H
# 1  ANTERO RESOURCES  CORPORATION  GUERNSEY  MILLWOOD      J ANDERSON     1H
# 2  ANTERO RESOURCES  CORPORATION  GUERNSEY  MILLWOOD      J ANDERSON     5H
# 3  ANTERO RESOURCES  CORPORATION  GUERNSEY  MILLWOOD      J ANDERSON     3H
# 4  ANTERO RESOURCES  CORPORATION  GUERNSEY  MILLWOOD      J ANDERSON     2H
#
#    Oil (Bbls)  Gas (Mcf)  Brine (Bbls)  Days in Production  \
# 0           0          0             0                  91
# 1         130      31334           324                  91
# 2         158      46773           209                  91
# 3         103      28393           254                  91
# 4          92      27276           242                  91
#
#   Date of First Production
# 0                      NaT
# 1               2013-11-11
# 2               2013-11-13
# 3               2013-11-13
# 4               2013-11-11
# (68326, 12)
# API Number                            int64
# Production Year                       int64
# Quarter (1, 2, 3, 4, n/a)             int64
# Owner Name                           object
# County                               object
# Township                             object
# Well Name and Number                 object
# Oil (Bbls)                            int64
# Gas (Mcf)                             int64
# Brine (Bbls)                          int64
# Days in Production                    int64
# Date of First Production     datetime64[ns]
# dtype: object

# %%
quarterly_production.describe()
# Out:
#          API Number  Production Year  Quarter (1, 2, 3, 4, n/a)  \
# count  6.832600e+04     68326.000000               68326.000000
# mean   3.405764e+13      2022.440389                   2.414732
# min    3.401321e+13      2020.000000                   1.000000
# 25%    3.401922e+13      2021.000000                   1.000000
# 50%    3.405925e+13      2023.000000                   2.000000
# 75%    3.408121e+13      2024.000000                   3.000000
# max    3.416926e+13      2025.000000                   4.000000
# std    3.937510e+10         1.599052                   1.113446
#
#           Oil (Bbls)     Gas (Mcf)   Brine (Bbls)  Days in Production  \
# count   68326.000000  6.832600e+04   68326.000000        68326.000000
# mean     2089.591781  1.755252e+05    2773.311302           84.935764
# min         0.000000  0.000000e+00       0.000000            0.000000
# 25%         0.000000  3.006325e+04     276.000000           90.000000
# 50%         0.000000  6.475750e+04     787.000000           91.000000
# 75%       488.000000  1.749745e+05    2419.000000           92.000000
# max    195194.000000  4.433897e+06  196980.000000         3919.000000
# std      9195.877042  3.453987e+05    6620.126847           24.313355
#
#             Date of First Production
# count                          66681
# mean   2017-04-02 14:38:17.853961472
# min              2007-11-26 00:00:00
# 25%              2014-11-29 00:00:00
# 50%              2016-12-23 00:00:00
# 75%              2019-04-24 00:00:00
# max              2025-08-18 00:00:00
# std                              NaN

# %%
quarterly_production['Quarter (1, 2, 3, 4, n/a)'].value_counts()
# Out:
# Quarter (1, 2, 3, 4, n/a)
# 2    18808
# 1    18414
# 4    15647
# 3    15457
# Name: count, dtype: int64

# %%
counts = quarterly_production.groupby(['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)']).size().reset_index(name='counts').sort_values(by='counts', ascending=False)
counts[counts['counts'] > 1]
# Out:
#            API Number  Production Year  Quarter (1, 2, 3, 4, n/a)  counts
# 20387  34019224510000             2021                          3       2
# 19925  34019224110000             2021                          3       2
# 5012   34013209650000             2022                          3       2
# 4770   34013209510000             2022                          3       2
# 2490   34013208090000             2022                          3       2
# ...               ...              ...                        ...     ...
# 7124   34013210970000             2022                          3       2
# 8165   34013211470000             2022                          3       2
# 21333  34019225280000             2021                          3       2
# 35433  34067210900000             2020                          1       2
# 40552  34067213740000             2024                          1       2
#
# [183 rows x 4 columns]

# %%
quarterly_production[quarterly_production[['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)']].duplicated(keep=False)].sort_values(by=['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)'])
# Out:
#            API Number  Production Year  Quarter (1, 2, 3, 4, n/a)  \
# 28106  34013206530000             2022                          3
# 30914  34013206530000             2022                          3
# 28107  34013206540100             2022                          3
# 30915  34013206540100             2022                          3
# 28125  34013207670000             2022                          3
# ...               ...              ...                        ...
# 53762  34111248760000             2024                          2
# 52875  34111248880000             2024                          2
# 53763  34111248880000             2024                          2
# 52876  34111248890000             2024                          2
# 53764  34111248890000             2024                          2
#
#                            Owner Name   County  Township  \
# 28106      ASCENT RESOURCES UTICA LLC  BELMONT      MEAD
# 30914                 XTO ENERGY INC.  BELMONT      MEAD
# 28107      ASCENT RESOURCES UTICA LLC  BELMONT      MEAD
# 30915                 XTO ENERGY INC.  BELMONT      MEAD
# 28125      ASCENT RESOURCES UTICA LLC  BELMONT  RICHLAND
# ...                               ...      ...       ...
# 53762             RICE DRILLING D LLC   MONROE      OHIO
# 52875  EQUINOR USA ONSHORE PROPERTIES   MONROE      OHIO
# 53763             RICE DRILLING D LLC   MONROE      OHIO
# 52876  EQUINOR USA ONSHORE PROPERTIES   MONROE      OHIO
# 53764             RICE DRILLING D LLC   MONROE      OHIO
#
#                  Well Name and Number  Oil (Bbls)  Gas (Mcf)  Brine (Bbls)  \
# 28106                   KALDOR     2H           0          0            77
# 30914                   KALDOR     2H           0          0             0
# 28107                   KALDOR     1H           0      22905           574
# 30915                   KALDOR     1H           0      10763           237
# 28125                COOK UNIT     2H           0      57533           554
# ...                               ...         ...        ...           ...
# 53762  R & D HILLTOP LUMBER     N U2H           0     146017          2461
# 52875                WEFLER S     U2H           0     230795          3759
# 53763                WEFLER S     U2H           0      35431           157
# 52876                WEFLER S     U1H           0          0             0
# 53764                WEFLER S     U1H           0          0             0
#
#        Days in Production Date of First Production
# 28106                   0               2014-01-10
# 30914                   0               2014-01-10
# 28107                  61               2013-12-10
# 30915                  31               2013-12-10
# 28125                  61               2015-05-12
# ...                   ...                      ...
# 53762                  30               2022-11-30
# 52875                  50               2020-11-20
# 53763                   5               2020-11-20
# 52876                   1               2020-11-19
# 53764                   0               2020-11-19
#
# [366 rows x 12 columns]

# %%
counts_2 = quarterly_production.groupby(['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)', 'Owner Name']).size().reset_index(name='counts').sort_values(by='counts', ascending=False)
counts_2[counts_2['counts'] > 1]
# Out:
# Empty DataFrame
# Columns: [API Number, Production Year, Quarter (1, 2, 3, 4, n/a), Owner Name, counts]
# Index: []

# %%
# No production, no days in production
print(quarterly_production[(quarterly_production['Oil (Bbls)'] == 0) & (quarterly_production['Gas (Mcf)'] == 0) & (quarterly_production['Brine (Bbls)'] == 0) & (quarterly_production['Days in Production'] == 0)].shape)
# No production, some days in production
print(quarterly_production[(quarterly_production['Oil (Bbls)'] == 0) & (quarterly_production['Gas (Mcf)'] == 0) & (quarterly_production['Brine (Bbls)'] == 0) & (quarterly_production['Days in Production'] > 0)].shape)
# Out:
# (1603, 12)
# (240, 12)

# %%
# Oil, gas, or brine production equal to zero
print(quarterly_production[(quarterly_production['Oil (Bbls)'] == 0)].shape)
print(quarterly_production[(quarterly_production['Gas (Mcf)'] == 0)].shape)
print(quarterly_production[(quarterly_production['Brine (Bbls)'] == 0)].shape)
# Out:
# (35584, 12)
# (2079, 12)
# (3438, 12)

# %%
import seaborn as sns

sns.pairplot(quarterly_production[['Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days in Production']])
# Out:
# c:\Users\willf\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\willf\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\willf\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\willf\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Remove clear outliers in days in production
quarterly_production = quarterly_production[quarterly_production['Days in Production'] <= 92]

sns.pairplot(quarterly_production[['Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days in Production']])
# Out:
# c:\Users\willf\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\willf\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\willf\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\willf\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import matplotlib.pyplot as plt
# Make histograms of production values
quarterly_production[['Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)']].hist(bins=50, figsize=(15, 5))
plt.show()

# %%
thresholds = {}

for col in ['Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)']:
    thresholds[col] = np.percentile(quarterly_production[col][quarterly_production[col] > 0], 90)
    quarterly_production.loc[(quarterly_production[col] > 0) & (quarterly_production[col] < thresholds[col]), col].hist(bins=20, figsize=(7, 5))
    plt.title(f'Histogram of {col} (0 < values < {thresholds[col]})')
    plt.show()

# %% [markdown]
# #### Notes from the Numerical Summary
#
# * We can see that the `quarter` column is numeric - there are no n/a values. Each row in the table corresponds with one well's production for one quarter.
# * There are duplicate records for some quarter/well/year combinations. These duplicates seem to be cases where the Owner Name is different - likely corresponding with the sale of a well.
#   + This can likely be checked with the permit plug dataset.
#   + These records do not necessarily need to be removed, but that is an option to consider.
# * 1843 rows have no production associated with them. 1603 of those have no production days. We likely should not remove those, but we may want to add a flag. The other 240 may need to be removed.
# * Some of the wells do not produce oil, some do not produce gas, and some do not produce oil.
#   + 35584 rows have no oil production.
#   + 2079 rows have no gas production (not many more than the total with no production).
#   + 3428 rows have no brine production.
# * We see severe right skew in the production values. Most wells are producing very little.
# * Even when filtering to the bottom 90% of values for each column (not including 0), there is severe right skew. Most wells produce very little.

# %% [markdown]
# ### Annual Production
#
# We want to combine the annual production records into one dataset.

# %%
# Ensure all annual dataframes have the same columns
annual_dfs = [annual_2010, annual_2011, annual_2012, annual_2013, annual_2014, annual_2015, annual_2016, annual_2017, annual_2018, annual_2019, annual_2020, annual_2021, annual_2022, annual_2023, annual_2024]
annual_dfs_names = ['annual_2010', 'annual_2011', 'annual_2012', 'annual_2013', 'annual_2014', 'annual_2015', 'annual_2016', 'annual_2017', 'annual_2018', 'annual_2019', 'annual_2020', 'annual_2021', 'annual_2022', 'annual_2023', 'annual_2024']
for i in range(1, len(annual_dfs)):
    for j in range(1, i):
        if not annual_dfs[i].columns.equals(annual_dfs[j].columns):
            print(f"Columns for annual dataframe {annual_dfs_names[i]} do not match the annual dataframe {annual_dfs_names[j]}.")

# Looks like columns for annual_2010 to annual_2017 do not match those for annual_2018 to annual_2024. Let's inspect further.
print(annual_2010.columns.tolist())
print(annual_2018.columns.tolist())
print(annual_2020.columns.tolist())
print(annual_2024.columns.tolist())

# Let's standardize these to match the quarterly production columns
annual_early = pd.concat(annual_dfs[:8], ignore_index=True)
annual_late = pd.concat(annual_dfs[9:13], ignore_index=True)
annual_really_late = pd.concat(annual_dfs[13:], ignore_index=True)
annual_early['Well Name and Number'] = annual_early['WELL NAME'] + ' ' + annual_early['WELL NUMBER']
annual_early = annual_early.rename(columns={
    'PRODUCTION YEAR': 'Production Year',
    'QUARTER: N/A, 1, 2, 3, 4': 'Quarter (1, 2, 3, 4, n/a)',
    'OWNER NAME': 'Owner Name',
    'API WELL NUMBER': 'API Number',
    'COUNTY': 'County',
    'TOWNSHIP': 'Township',
    'OIL': 'Oil (Bbls)',
    'GAS': 'Gas (Mcf)',
    'BRINE': 'Brine (Bbls)',
    'Days': 'Days in Production',
    'DATE OF FIRST PRODUCTION': 'Date of First Production',
}).drop(columns=['WELL NAME', 'WELL NUMBER'])
annual_2018 = annual_2018.rename(columns={
    'Quarter 1, 2, 3, 4, n/a': 'Quarter (1, 2, 3, 4, n/a)',
    'Days': 'Days in Production',
})
annual_late = annual_late.rename(columns={'Days': 'Days in Production'})

print(annual_early.columns.tolist())
print(annual_2018.columns.tolist())
print(annual_late.columns.tolist())
print(annual_really_late.columns.tolist())

annual_production = pd.concat([annual_early, annual_2018, annual_late, annual_really_late], ignore_index=True)
display(annual_production.head(5))
# Out:
# Columns for annual dataframe annual_2018 do not match the annual dataframe annual_2011.
# Columns for annual dataframe annual_2018 do not match the annual dataframe annual_2012.
# Columns for annual dataframe annual_2018 do not match the annual dataframe annual_2013.
# Columns for annual dataframe annual_2018 do not match the annual dataframe annual_2014.
# Columns for annual dataframe annual_2018 do not match the annual dataframe annual_2015.
# Columns for annual dataframe annual_2018 do not match the annual dataframe annual_2016.
# Columns for annual dataframe annual_2018 do not match the annual dataframe annual_2017.
# Columns for annual dataframe annual_2019 do not match the annual dataframe annual_2011.
# Columns for annual dataframe annual_2019 do not match the annual dataframe annual_2012.
# Columns for annual dataframe annual_2019 do not match the annual dataframe annual_2013.
# Columns for annual dataframe annual_2019 do not match the annual dataframe annual_2014.
# Columns for annual dataframe annual_2019 do not match the annual dataframe annual_2015.
# Columns for annual dataframe annual_2019 do not match the annual dataframe annual_2016.
# Columns for annual dataframe annual_2019 do not match the annual dataframe annual_2017.
# Columns for annual dataframe annual_2019 do not match the annual dataframe annual_2018.
# Columns for annual dataframe annual_2020 do not match the annual dataframe annual_2011.
# Columns for annual dataframe annual_2020 do not match the annual dataframe annual_2012.
# Columns for annual dataframe annual_2020 do not match the annual dataframe annual_2013.
# Columns for annual dataframe annual_2020 do not match the annual dataframe annual_2014.
# Columns for annual dataframe annual_2020 do not match the annual dataframe annual_2015.
# Columns for annual dataframe annual_2020 do not match the annual dataframe annual_2016.
# Columns for annual dataframe annual_2020 do not match the annual dataframe annual_2017.
# Columns for annual dataframe annual_2020 do not match the annual dataframe annual_2018.
# Columns for annual dataframe annual_2021 do not match the annual dataframe annual_2011.
# Columns for annual dataframe annual_2021 do not match the annual dataframe annual_2012.
# Columns for annual dataframe annual_2021 do not match the annual dataframe annual_2013.
# Columns for annual dataframe annual_2021 do not match the annual dataframe annual_2014.
# Columns for annual dataframe annual_2021 do not match the annual dataframe annual_2015.
# Columns for annual dataframe annual_2021 do not match the annual dataframe annual_2016.
# Columns for annual dataframe annual_2021 do not match the annual dataframe annual_2017.
# Columns for annual dataframe annual_2021 do not match the annual dataframe annual_2018.
# Columns for annual dataframe annual_2022 do not match the annual dataframe annual_2011.
# Columns for annual dataframe annual_2022 do not match the annual dataframe annual_2012.
# Columns for annual dataframe annual_2022 do not match the annual dataframe annual_2013.
# Columns for annual dataframe annual_2022 do not match the annual dataframe annual_2014.
# Columns for annual dataframe annual_2022 do not match the annual dataframe annual_2015.
# Columns for annual dataframe annual_2022 do not match the annual dataframe annual_2016.
# Columns for annual dataframe annual_2022 do not match the annual dataframe annual_2017.
# Columns for annual dataframe annual_2022 do not match the annual dataframe annual_2018.
# Columns for annual dataframe annual_2023 do not match the annual dataframe annual_2011.
# Columns for annual dataframe annual_2023 do not match the annual dataframe annual_2012.
# Columns for annual dataframe annual_2023 do not match the annual dataframe annual_2013.
# Columns for annual dataframe annual_2023 do not match the annual dataframe annual_2014.
# Columns for annual dataframe annual_2023 do not match the annual dataframe annual_2015.
# Columns for annual dataframe annual_2023 do not match the annual dataframe annual_2016.
# Columns for annual dataframe annual_2023 do not match the annual dataframe annual_2017.
# Columns for annual dataframe annual_2023 do not match the annual dataframe annual_2018.
# Columns for annual dataframe annual_2023 do not match the annual dataframe annual_2019.
# Columns for annual dataframe annual_2023 do not match the annual dataframe annual_2020.
# Columns for annual dataframe annual_2023 do not match the annual dataframe annual_2021.
# Columns for annual dataframe annual_2023 do not match the annual dataframe annual_2022.
# Columns for annual dataframe annual_2024 do not match the annual dataframe annual_2011.
# Columns for annual dataframe annual_2024 do not match the annual dataframe annual_2012.
# Columns for annual dataframe annual_2024 do not match the annual dataframe annual_2013.
# Columns for annual dataframe annual_2024 do not match the annual dataframe annual_2014.
# Columns for annual dataframe annual_2024 do not match the annual dataframe annual_2015.
# Columns for annual dataframe annual_2024 do not match the annual dataframe annual_2016.
# Columns for annual dataframe annual_2024 do not match the annual dataframe annual_2017.
# Columns for annual dataframe annual_2024 do not match the annual dataframe annual_2018.
# Columns for annual dataframe annual_2024 do not match the annual dataframe annual_2019.
# Columns for annual dataframe annual_2024 do not match the annual dataframe annual_2020.
# Columns for annual dataframe annual_2024 do not match the annual dataframe annual_2021.
# Columns for annual dataframe annual_2024 do not match the annual dataframe annual_2022.
# ['PRODUCTION YEAR', 'QUARTER: N/A, 1, 2, 3, 4', 'OWNER NAME', 'API WELL NUMBER', 'COUNTY', 'TOWNSHIP', 'WELL NAME', 'WELL NUMBER', 'OIL', 'GAS', 'BRINE', 'Days', 'DATE OF FIRST PRODUCTION']
# ['API Number', 'Production Year', 'Quarter 1, 2, 3, 4, n/a', 'Owner Name', 'County', 'Township', 'Well Name and Number', 'Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days', 'Date of First Production']
# ['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)', 'Owner Name', 'County', 'Township', 'Well Name and Number', 'Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days', 'Date of First Production']
# ['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)', 'Owner Name', 'County', 'Township', 'Well Name and Number', 'Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days in Production', 'Date of First Production']
# ['Production Year', 'Quarter (1, 2, 3, 4, n/a)', 'Owner Name', 'API Number', 'County', 'Township', 'Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days in Production', 'Date of First Production', 'Well Name and Number']
# ['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)', 'Owner Name', 'County', 'Township', 'Well Name and Number', 'Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days in Production', 'Date of First Production']
# ['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)', 'Owner Name', 'County', 'Township', 'Well Name and Number', 'Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days in Production', 'Date of First Production']
# ['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)', 'Owner Name', 'County', 'Township', 'Well Name and Number', 'Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)', 'Days in Production', 'Date of First Production']
#    Production Year  Quarter (1, 2, 3, 4, n/a)               Owner Name  \
# 0             2010                        NaN      AB RESOURCES OH LLC
# 1             2010                        NaN     Hottel Oil & Gas LLC
# 2             2010                        NaN  SHORTS RALPH E DRILLING
# 3             2010                        NaN      AB RESOURCES OH LLC
# 4             2010                        NaN     Hottel Oil & Gas LLC
#
#        API Number   County Township  Oil (Bbls)  Gas (Mcf)  Brine (Bbls)  \
# 0  34005200230000  ASHLAND    PERRY         0.0        0.0           0.0
# 1  34005200330000  ASHLAND  JACKSON         0.0        0.0           0.0
# 2  34005200580000  ASHLAND  JACKSON        33.0        0.0          12.0
# 3  34005200690000  ASHLAND  MOHICAN         0.0        0.0           0.0
# 4  34005201080000  ASHLAND  JACKSON         0.0     1124.0           0.0
#
#    Days in Production Date of First Production  \
# 0               365.0                      NaT
# 1                 0.0                      NaT
# 2               365.0                      NaT
# 3               365.0                      NaT
# 4               365.0                      NaT
#
#                    Well Name and Number
# 0  AGNES McKINEY (MORR)     1-582 1-582
# 1         HEFFELINGER     1-5874 1-5874
# 2                  STANISLAWSKI     1 1
# 3    HOYLAND B AUSTIN(CRUMLICK)     1 1
# 4                       L. HALL     1 1

# %%
# Basic description
print(annual_production.shape)
print(annual_production.dtypes)
annual_production.describe()
# Out:
# (864289, 12)
# Production Year                       int64
# Quarter (1, 2, 3, 4, n/a)           float64
# Owner Name                           object
# API Number                            int64
# County                               object
# Township                             object
# Oil (Bbls)                          float64
# Gas (Mcf)                           float64
# Brine (Bbls)                        float64
# Days in Production                  float64
# Date of First Production     datetime64[ns]
# Well Name and Number                 object
# dtype: object
#        Production Year  Quarter (1, 2, 3, 4, n/a)    API Number  \
# count    864289.000000              100081.000000  8.642890e+05
# mean       2017.191158                   2.548046  3.409966e+13
# min        2010.000000                   1.000000  3.400723e+11
# 25%        2014.000000                   2.000000  3.405924e+13
# 50%        2017.000000                   3.000000  3.411123e+13
# 75%        2021.000000                   4.000000  3.415124e+13
# max        2024.000000                   4.000000  3.497522e+13
# std           4.199843                   1.116009  6.334027e+10
#
#           Oil (Bbls)     Gas (Mcf)   Brine (Bbls)  Days in Production  \
# count  864092.000000  8.640360e+05  863276.000000       842548.000000
# mean      332.874133  2.474732e+04     404.514622          277.918185
# min         0.000000 -2.820000e+02     -77.000000          -15.000000
# 25%         0.000000  0.000000e+00       0.000000          120.000000
# 50%         0.000000  3.890000e+02       0.000000          365.000000
# 75%        68.000000  1.670000e+03      55.000000          365.000000
# max    187202.000000  4.433897e+06  730000.000000         3919.000000
# std      3018.068124  1.404743e+05    2538.547113          140.073895
#
#             Date of First Production
# count                         443132
# mean   1997-06-27 11:39:14.641055360
# min              1895-01-01 00:00:00
# 25%              1984-11-08 00:00:00
# 50%              1993-09-01 00:00:00
# 75%              2011-09-30 00:00:00
# max              2025-03-25 00:00:00
# std                              NaN

# %%
# Examine rows with null production values
annual_production[annual_production[['Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)']].isnull().any(axis=1)]
# Out:
#         Production Year  Quarter (1, 2, 3, 4, n/a)             Owner Name  \
# 696                2010                        NaN   SUMMIT PETROLEUM INC
# 707                2010                        NaN      DIETRICH PHILIP H
# 724                2010                        NaN      DIETRICH PHILIP H
# 730                2010                        NaN      DIETRICH PHILIP H
# 777                2010                        NaN      DIETRICH PHILIP H
# ...                 ...                        ...                    ...
# 412172             2017                        NaN    G-R CONTRACTING INC
# 436830             2017                        NaN  STANDARD OIL CO OF WV
# 438802             2017                        NaN    B & E RESOURCES LLC
# 680269             2021                        NaN         AM-TEK OIL INC
# 833341             2024                        NaN        BANDS GROUP LLC
#
#             API Number      County   Township  Oil (Bbls)  Gas (Mcf)  \
# 696     34007200050000   ASHTABULA   CONNEAUT         0.0        0.0
# 707     34007200980000   ASHTABULA   RICHMOND         0.0        0.0
# 724     34007202220000   ASHTABULA      LENOX         0.0      361.0
# 730     34007202310000   ASHTABULA      LENOX         0.0      480.0
# 777     34007203640000   ASHTABULA      LENOX         0.0        0.0
# ...                ...         ...        ...         ...        ...
# 412172  34111243160000      MONROE     SUMMIT        91.0        0.0
# 436830  34167215820000  WASHINGTON     BARLOW         NaN       64.0
# 438802  34167257810000  WASHINGTON      ADAMS        17.0      600.0
# 680269  34153216110000      SUMMIT  RICHFIELD         0.0      217.0
# 833341  34075223870000      HOLMES   MECHANIC        13.0      159.0
#
#         Brine (Bbls)  Days in Production Date of First Production  \
# 696              NaN                 NaN                      NaT
# 707              NaN                 NaN                      NaT
# 724              NaN                 NaN                      NaT
# 730              NaN                 NaN                      NaT
# 777              NaN                 NaN                      NaT
# ...              ...                 ...                      ...
# 412172           NaN               365.0               2012-06-07
# 436830           0.0               365.0                      NaT
# 438802           NaN               365.0                      NaT
# 680269           NaN               365.0               1984-04-18
# 833341           NaN               120.0               1981-01-01
#
#                        Well Name and Number
# 696                         HOLMES JOHN 1 1
# 707          EDMUND & MARY RONAMOWSKI # 1 1
# 724                     MARY HAMILTON # 1 1
# 730     DONALD O & DELORES M DIETRICH # 1 1
# 777                    ROBERT A. KATO # 1 1
# ...                                     ...
# 412172                RUBEL-BILLMAN     1 1
# 436830                    HOLLY MCCOY # 1 1
# 438802                          SZAKAS #1 1
# 680269                       H JAEGER     1
# 833341                               MULLET
#
# [1435 rows x 12 columns]

# %%
# Examine negative production values
display(annual_production[(annual_production['Oil (Bbls)'] < 0) | (annual_production['Gas (Mcf)'] < 0) | (annual_production['Brine (Bbls)'] < 0) | (annual_production['Days in Production'] < 0)])
annual_production[(annual_production['Oil (Bbls)'] < 0) | (annual_production['Gas (Mcf)'] < 0) | (annual_production['Brine (Bbls)'] < 0) | (annual_production['Days in Production'] < 0)].shape
# Out:
#         Production Year  Quarter (1, 2, 3, 4, n/a)  \
# 58037              2011                        NaN
# 58179              2011                        NaN
# 64304              2011                        NaN
# 71834              2011                        NaN
# 71839              2011                        NaN
# 71841              2011                        NaN
# 71842              2011                        NaN
# 72361              2011                        NaN
# 85137              2011                        NaN
# 177673             2013                        NaN
# 177696             2013                        NaN
# 189857             2013                        NaN
# 194878             2013                        NaN
# 226328             2014                        NaN
# 334807             2016                        NaN
# 388883             2017                        NaN
# 390551             2017                        NaN
# 391279             2017                        NaN
# 393979             2017                        NaN
# 441879             2017                        NaN
# 460083             2018                        1.0
# 477650             2018                        NaN
# 694875             2022                        NaN
# 731100             2022                        NaN
# 737756             2022                        NaN
# 737759             2022                        NaN
# 737760             2022                        NaN
#
#                             Owner Name      API Number      County  \
# 58037                ATLAS AMERICA LLC  34031259810000   COSHOCTON
# 58179                ATLAS AMERICA LLC  34031261720000   COSHOCTON
# 64304        KILLBUCK OILFIELD SERVICE  34075225360000      HOLMES
# 71834            A S N F PRODUCING INC  34103218350000      MEDINA
# 71839            A S N F PRODUCING INC  34103218430000      MEDINA
# 71841            A S N F PRODUCING INC  34103218480000      MEDINA
# 71842            A S N F PRODUCING INC  34103218550000      MEDINA
# 72361              G & O RESOURCES LTD  34103236330000      MEDINA
# 85137        EVERFLOW EASTERN PTNS L P  34133234880000     PORTAGE
# 177673              OLD SOUTH OIL, LLC  34105215760000       MEIGS
# 177696              OLD SOUTH OIL, LLC  34105216180000       MEIGS
# 189857  Everflow Eastern Partners, L.P  34133234880000     PORTAGE
# 194878  OHIO VALLEY ENERGY SYSTEM CORP  34153229950000      SUMMIT
# 226328                KNOX ENERGY INC.  34083246160000        KNOX
# 334807           M & R INVESTMENTS LLC  34067210110000    HARRISON
# 388883                 Atlas Noble LLC  34029212710000  COLUMBIANA
# 390551           NORTHWOOD ENERGY CORP  34031242880000   COSHOCTON
# 391279       M&R Investments Ohio, LLC  34031260970000   COSHOCTON
# 393979          ENERVEST OPERATING LLC  34055212280000      GEAUGA
# 441879              C&C PRODUCING, LLC  34169216600000       WAYNE
# 460083      ASCENT RESOURCES UTICA LLC  34059243680000    GUERNSEY
# 477650    STONEBRIDGE OPERATING CO LLC  34115217680000      MORGAN
# 694875           NORTHWOOD ENERGY CORP  34007238000000   ASHTABULA
# 731100           NORTHWOOD ENERGY CORP  34119244330000   MUSKINGUM
# 737756     PIN OAK ENERGY PARTNERS LLC  34133220080000     PORTAGE
# 737759     PIN OAK ENERGY PARTNERS LLC  34133220110000     PORTAGE
# 737760     PIN OAK ENERGY PARTNERS LLC  34133220140000     PORTAGE
#
#             Township  Oil (Bbls)  Gas (Mcf)  Brine (Bbls)  Days in Production  \
# 58037      LAFAYETTE         0.0     -176.0          48.0               365.0
# 58179      LAFAYETTE         0.0      -23.0           0.0                18.0
# 64304       MECHANIC         0.0      -12.0           0.0               365.0
# 71834          HOMER         0.0       -5.0           0.0               365.0
# 71839          HOMER         0.0       -6.0           0.0               365.0
# 71841          HOMER         0.0       -9.0           0.0               365.0
# 71842          HOMER         0.0       -3.0           0.0               365.0
# 72361        GRANGER         0.0      -63.0           0.0                 0.0
# 85137       EDINBURG       155.0     -234.0          63.0                 0.0
# 177673       RUTLAND         0.0       -3.0           0.0                 0.0
# 177696       RUTLAND         0.0       -3.0           0.0                 0.0
# 189857      EDINBURG       114.0      -91.0          85.0               365.0
# 194878      COVENTRY         0.0     -282.0         146.0               238.0
# 226328        BERLIN       586.0        0.0           0.0               -15.0
# 334807         STOCK         0.0      544.0         -24.0               365.0
# 388883       HANOVER         0.0       -1.0           0.0               182.0
# 390551      CRAWFORD         0.0       35.0          -5.0               365.0
# 391279       JACKSON         0.0      -22.0           0.0               182.0
# 393979     HUNTSBURG        42.0        0.0         -10.0               193.0
# 441879        MILTON        78.0      528.0         -25.0               365.0
# 460083   LONDONDERRY       735.0     8828.0         -28.0                 6.0
# 477650         MALTA         0.0       53.0         -21.0               280.0
# 694875        DORSET         0.0       -1.0           0.0                 0.0
# 731100         UNION         0.0        0.0         -77.0                 0.0
# 737756   STREETSBORO         0.0       -3.0           0.0                 0.0
# 737759   STREETSBORO         0.0       -3.0           0.0                 0.0
# 737760  SHALERSVILLE         0.0       -3.0           0.0                 0.0
#
#        Date of First Production            Well Name and Number
# 58037                       NaT        PAUL CARLISLE UNIT # 2 2
# 58179                       NaT              LARRY REHARD # 9 9
# 64304                       NaT              ALBERT RABER # 1 1
# 71834                       NaT                             NaN
# 71839                       NaT                             NaN
# 71841                       NaT                             NaN
# 71842                       NaT               BISHOP-JEDLICKA 1
# 72361                1984-04-12              SUTPHIN UNIT # 1 1
# 85137                1985-12-28         BRONKO ASSOCIATES # 2 2
# 177673                      NaT  MILO & BETTY HUTCHESON     1 1
# 177696                      NaT  MILO & BETTY HUTCHESON     2 2
# 189857               1985-12-28         BRONKO ASSOCIATES # 2 2
# 194878               2007-07-02                  FOWLER     1 1
# 226328               2014-10-15       WHITE R     1-3764 1-3764
# 334807               2007-07-21              ROSS WELLS     1 1
# 388883                      NaT              ELLYSON C.     1 1
# 390551                      NaT        WELLING CARROLL  1-4 1-4
# 391279                      NaT       OLINGER/DEWITT UNIT # 2 2
# 393979                      NaT              ENGEL # 1 (1727) 1
# 441879                      NaT                     ZOOK L  2 2
# 460083               2015-04-14                   WAGLER     1H
# 477650                      NaT                       D. LOWE 2
# 694875               1988-11-22                      COMP # 1-A
# 731100               1984-01-01                DOROTHY ANDERSON
# 737756               1984-01-01          STREETSBORO     #7-383
# 737759               1980-01-01          STREETSBORO UNIT     4
# 737760               1980-01-01             STREETSBORO # 8-386
# (27, 12)

# %%
# Find annual production entries that have corresponding quarterly production entries
annual_with_quarterly = annual_production.merge(
    quarterly_production[['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)']],
    on=['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)'],
    how='inner'
)
annual_with_quarterly.shape
# Out:
# (61427, 12)

# %%
annual_production[(annual_production['Production Year'] < 2020) & (~annual_production['Quarter (1, 2, 3, 4, n/a)'].isnull())]
# Out:
#         Production Year  Quarter (1, 2, 3, 4, n/a)  \
# 158413             2013                        1.0
# 158414             2013                        2.0
# 158415             2013                        3.0
# 158416             2013                        4.0
# 158434             2013                        1.0
# ...                 ...                        ...
# 563269             2019                        4.0
# 565900             2019                        1.0
# 565901             2019                        2.0
# 565902             2019                        3.0
# 565903             2019                        4.0
#
#                           Owner Name      API Number      County    Township  \
# 158413              XTO ENERGY, INC.  34013205830000     BELMONT  WASHINGTON
# 158414              XTO ENERGY, INC.  34013205830000     BELMONT  WASHINGTON
# 158415               XTO ENERGY INC.  34013205830000     BELMONT  WASHINGTON
# 158416               XTO ENERGY INC.  34013205830000     BELMONT  WASHINGTON
# 158434       HESS OHIO RESOURCES LLC  34013206190000     BELMONT    RICHLAND
# ...                              ...             ...         ...         ...
# 563269  UTICA RESOURCE OPERATING LLC  34167297610100  WASHINGTON   WATERFORD
# 565900                  GEOPETRO LLC  34169256690100       WAYNE  EAST UNION
# 565901                  GEOPETRO LLC  34169256690100       WAYNE  EAST UNION
# 565902                  GEOPETRO LLC  34169256690100       WAYNE  EAST UNION
# 565903                  GEOPETRO LLC  34169256690100       WAYNE  EAST UNION
#
#         Oil (Bbls)  Gas (Mcf)  Brine (Bbls)  Days in Production  \
# 158413         0.0      163.0           0.0                 7.0
# 158414         0.0        0.0           0.0                 0.0
# 158415         0.0        0.0           0.0                 0.0
# 158416         0.0        0.0           0.0                 0.0
# 158434         0.0        0.0           0.0                 0.0
# ...            ...        ...           ...                 ...
# 563269      1172.0    20154.0         516.0                92.0
# 565900         0.0     4473.0           0.0                90.0
# 565901         0.0     7005.0          56.0                89.0
# 565902        88.0     6997.0           0.0                91.0
# 565903         0.0    11949.0          80.0                68.0
#
#        Date of First Production                    Well Name and Number
# 158413               2007-11-26                 BOAN/MARCUM     2-1 2-1
# 158414               2007-11-26                 BOAN/MARCUM     2-1 2-1
# 158415               2007-11-26                 BOAN/MARCUM     2-1 2-1
# 158416               2007-11-26                 BOAN/MARCUM     2-1 2-1
# 158434                      NaT  PORTERFIELD GAS UNIT B     1H-17 1H-17
# ...                         ...                                     ...
# 563269               2016-06-14                            MASON     2H
# 565900               2012-11-07                      HERSHBERGER     1H
# 565901               2012-11-07                      HERSHBERGER     1H
# 565902               2012-11-07                      HERSHBERGER     1H
# 565903               2012-11-07                      HERSHBERGER     1H
#
# [38973 rows x 12 columns]

# %%
annual_production = annual_production[(annual_production['Oil (Bbls)'] >= 0) & (annual_production['Gas (Mcf)'] >= 0) & (annual_production['Brine (Bbls)'] >= 0) & (annual_production['Days in Production'] >= 0)]
annual_production = annual_production[(annual_production['Production Year'] < 2020) | (annual_production['Quarter (1, 2, 3, 4, n/a)'].isnull())]

# %%
annual_with_quarterly = annual_production.merge(
    quarterly_production[['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)']],
    on=['API Number', 'Production Year', 'Quarter (1, 2, 3, 4, n/a)'],
    how='inner'
)
annual_with_quarterly.shape
# Out:
# (0, 12)

# %%
annual_production = annual_production[annual_production['Days in Production'] <= 366]

# %%
annual_production[['Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)']].hist(bins=50, figsize=(15, 5))
plt.show()

# %%
thresholds = {}
for col in ['Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)']:
    thresholds[col] = np.percentile(annual_production[col][annual_production[col] > 0], 90)
    annual_production.loc[(annual_production[col] > 0) & (annual_production[col] < thresholds[col]), col].hist(bins=20, figsize=(7, 5))
    plt.title(f'Histogram of {col} (0 < values < {thresholds[col]})')
    plt.show()

# %% [markdown]
# ### Notes from Numerical Summary
#
# * Notably, there are null values in the production columns for 1435 rows. Most of them have only one null column, so we can probably coalesce those to be 0.
# * There are 27 rows with negative production values. We can remove these, and may want to consider removing these wells entirely.
# * There are 100,000+ rows with quarterly values. We already have quarterly values for 2020 and beyond, but we should keep the quarterly values for 2019 and earlier.
#   + 61,427 of these rows are accounted for already by `quarterly_production`.
#   + After removing the non-null quarters for 2020 and beyond, there is no overlap between `quarterly_production` and `annual_production`.
# * Like with quarterly production, over half of the rows have 0 for brine and oil.
# * We can also see the same heavy right skew, even when filtering down to the bottom 90% of values.

# %% [markdown]
# ### Combining Quarterly and Annual Data
#
# Since the data has the same rows, we can combine the quarterly and annual data to be in one dataset. We can also separate the quarterly data that is currently stored in the annual dataset.

# %%
annual_and_quarterly = pd.concat([annual_production, quarterly_production], ignore_index=True) 
annual_final = annual_and_quarterly[annual_and_quarterly['Quarter (1, 2, 3, 4, n/a)'].isnull()]
quarterly_final = annual_and_quarterly[~annual_and_quarterly['Quarter (1, 2, 3, 4, n/a)'].isnull()]

# %%
# Write final datasets to CSV files
annual_final.to_csv('../data/final/annual_production_final.csv', index=False)
quarterly_final.to_csv('../data/final/quarterly_production_final.csv', index=False)
annual_and_quarterly.to_csv('../data/final/annual_and_quarterly_production_final.csv', index=False)

# %% [markdown]
# ### Permit Plug List
#
# We need to read in each file from the `permit_plug` folder.

# %%
# Read each file from the permit_plug folder.
import os

permit_plug_folder = '../data/permit_plug/'
permit_plug_files = [f for f in os.listdir(permit_plug_folder) if f.endswith('.xls')]

permit_plug_list = pd.concat([pd.read_excel(permit_plug_folder + f) for f in permit_plug_files], ignore_index=True)
# Out:
# WARNING *** file size (1022733) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1796790) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1195456) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1667149) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1692979) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1797077) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1441763) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1798699) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1163415) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1319610) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1870852) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1438167) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1090930) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (969059) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (969059) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1069376) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (995826) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1146901) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1412196) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1302056) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (792712) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (962332) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1042125) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (740534) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1132632) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1381795) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1499865) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1331858) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1423180) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1255411) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (826040) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1385416) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1697427) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1668389) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1422973) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1773940) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1318777) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1611538) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1733766) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1680026) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (840254) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1557786) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1104147) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1312407) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1249093) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1314238) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1314238) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1632108) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1563362) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1715567) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1425127) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1152825) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1610095) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1409611) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1271781) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1574971) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1578130) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1564912) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1763545) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1405777) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (862658) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1372871) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (756152) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
permit_plug_list.columns.to_list()
# Out:
# ['NAME',
#  'WH_LOT',
#  'WH_SEC',
#  'WH_LAT83',
#  'WH_LONG83',
#  'WH_LAT',
#  'WH_LONG',
#  'QUAD_NAME',
#  'CONAME',
#  'ADDR1',
#  'ADDR2',
#  'CITY',
#  'STATE',
#  'ZIP1',
#  'PHONE',
#  'CNTY_APINO',
#  'WH_CV_TWPNO',
#  'CV_TWPNM',
#  'DT_APP_ISSUED',
#  'APP_TYP',
#  'APPNO',
#  'DT_APP_RECVD',
#  'YN_RUSH_APP',
#  'RUSH_CHKNO',
#  'RUSH_AMT',
#  'APP_CHKNO',
#  'FEE_AMT',
#  'REVISED_AMT',
#  'REVISED_CHKNO',
#  'VARIANCE',
#  'POOL_AMT',
#  'OPNO',
#  'CO_REP',
#  'PM_ADDROK',
#  'PM_CONTACT',
#  'PM_ADDR1',
#  'PM_ADDR2',
#  'PM_CITY',
#  'PM_STATE',
#  'PM_ZIP1',
#  'PM_ZIP2',
#  'PM_COUNTRY',
#  'PM_PHONENO',
#  'EXIST_WELL',
#  'LOCATION_ID',
#  'WELLNM',
#  'WELLNO',
#  'DU_ACRES',
#  'RIG_TYP',
#  'FIRE_PHNO',
#  'MEDL_PHNO',
#  'PROP_WLTYPE',
#  'PROP_TD',
#  'PROP_WELL_CLASS',
#  'PROPOSEDFORMATIONS',
#  'ELEV_GR',
#  'ELEV_TGT',
#  'API_WELLNO',
#  'WH_FTCALLS',
#  'BH_LOT',
#  'BH_SEC',
#  'BH_FTCALLS',
#  'BH_ALLOTMENT',
#  'BH_X',
#  'BH_Y',
#  'BH_OGS_QUADCODE',
#  'BH_CV_TWPNO',
#  'QUAD_NAME_T',
#  'APP_TYP_Description',
#  'BH_CV_TWPNM',
#  ' NAME']

# %% [markdown]
# This dataset has way too many columns. We are looking to use this exclusively to determine well type and well status, so we can limit the columns we use.

# %%
# Fill NA values in 'NAME' with values from ' NAME'
permit_plug_list['NAME'] = permit_plug_list[' NAME'].fillna(permit_plug_list['NAME'])

permit_plug_list = permit_plug_list[[
    'API_WELLNO', 'WH_LAT', 'WH_LONG', 'CONAME', 'DT_APP_ISSUED', 'DT_APP_RECVD',
    'APP_TYP', 'APPNO', 'EXIST_WELL', 'LOCATION_ID', 'RIG_TYP', 'PROP_WLTYPE',
    'PROP_WELL_CLASS', 'APP_TYP_Description'
]]

# %% [markdown]
# For this dataset, we are going to need a lot of client clarification about what any of these columns mean.

# %%
permit_plug_list.shape
# Out:
# (45474, 14)

# %%
# Count nulls in each column
permit_plug_list.isnull().sum()
# Out:
# API_WELLNO                 0
# WH_LAT                  1706
# WH_LONG                 1706
# CONAME                     8
# DT_APP_ISSUED              0
# DT_APP_RECVD               0
# APP_TYP                    0
# APPNO                      0
# EXIST_WELL                 0
# LOCATION_ID                0
# RIG_TYP                 2588
# PROP_WLTYPE                3
# PROP_WELL_CLASS        19791
# APP_TYP_Description        4
# dtype: int64

# %% [markdown]
# We see that we have some null values in WH_LAT and WH_LONG. We hope for those gaps to be filled in by the Well Information dataset. There are also lots of null values in the PROP_WELL_CLASS column, but few in the PROP_WLTYPE column.

# %%
permit_plug_list['PROP_WLTYPE'].value_counts()
# Out:
# PROP_WLTYPE
# OG_R    43204
# ST_R      948
# GS_R      539
# SW_R      414
# ER_R      173
# SM_R      132
# UN_R       37
# OG         10
# BR_R        7
# MN_R        6
# SWD         1
# Name: count, dtype: int64

# %%
permit_plug_list[permit_plug_list['PROP_WELL_CLASS'] == 'SWIW'].shape
# Out:
# (315, 14)

# %%
# Check duplicated rows
print(permit_plug_list.duplicated().sum())
# Remove duplicated rows
permit_plug_list = permit_plug_list.drop_duplicates()
print(permit_plug_list.duplicated().sum())
# Out:
# 2313
# 0

# %% [markdown]
# We need more clarification on the types and classes of wells, but it appears that of the 414 SWIWs, we have 315 with non-null well class.

# %%
permit_plug_list.to_csv('../data/final/permit_plug_list_final.csv', index=False)

# %% [markdown]
# ### Well Information
#
# We need to aggregate all of the well information files for each county.

# %%
well_information_folder = '../data/well_information/'
well_info_files = [f for f in os.listdir(well_information_folder) if f.endswith('.xls')]

well_info = pd.concat([pd.read_excel(well_information_folder + f) for f in well_info_files], ignore_index=True)
# Out:
# WARNING *** file size (17479) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1107595) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1224501) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (761372) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (254392) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (475323) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (954416) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (840344) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1395761) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (298785) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (16187) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (240000) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (308809) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (615616) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (894748) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (97888) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (25765) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (586789) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (812075) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1275894) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (45819) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (46538) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (282155) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (963820) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (239762) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (173174) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (18342) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (342485) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1247390) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (958881) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (864057) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (62524) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1668291) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (939698) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (146478) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1521438) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1133070) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (24735) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (904689) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (31156) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (29427) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1273714) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (169188) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (88470) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (87029) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (46130) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (24990) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1859293) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (797790) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1367268) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1695764) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (172404) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (3149844) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (1365255) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (178730) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (48087) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
well_info.shape
# Out:
# (75294, 17)

# %%
well_info.columns
# Out:
# Index(['API WELL NUMBER', 'CV_TWPNM', 'CONAME', 'Company Phone', 'WELL NAME',
#        'WELL NUMBER', 'PRODUCING FORMATION', 'COMPLETED DATE', 'SECTION',
#        'LOT', 'WELL LATITUDE', 'WELL LONGITUDE', 'TANK LATITUDE',
#        'TANK LONGITUDE', 'NUMBER OF STORAGE TANKS', 'MAXIMUM STORAGE CAPACITY',
#        'CNTY_APINO'],
#       dtype='object')

# %%
well_info.isnull().sum()
# Out:
# API WELL NUMBER                 0
# CV_TWPNM                        5
# CONAME                          0
# Company Phone                 382
# WELL NAME                      65
# WELL NUMBER                   463
# PRODUCING FORMATION          9992
# COMPLETED DATE              12622
# SECTION                     19586
# LOT                         50925
# WELL LATITUDE                1669
# WELL LONGITUDE               1687
# TANK LATITUDE               32699
# TANK LONGITUDE              32694
# NUMBER OF STORAGE TANKS     19779
# MAXIMUM STORAGE CAPACITY    19810
# CNTY_APINO                      0
# dtype: int64

# %% [markdown]
# There is a lot of missing data here. Notably, we are missing latitudes and longitudes for some wells, as well as completed dates. We should drop rows without well latitude and well longitude.

# %%
well_info = well_info[(~well_info['WELL LATITUDE'].isnull()) & (~well_info['WELL LONGITUDE'].isnull())]

# %%
# Check duplicated rows
well_info.duplicated().sum()
# Out:
# 0

# %%
well_info.to_csv('../data/final/well_information_final.csv', index=False)

# %% [markdown]
# ### Active Owners

# %%
well_owners.head(5)
# Out:
#    Company #  Status                                       Company Name  \
# 0       9695  Active                                     3200 SCIO, LLC
# 1       9782  Active                                  4M ENTERPRISE LLC
# 2       9783  Active  A & R OIL & GAS OF MONROE & WASHINGTON COUNTIE...
# 3       1890  Active                               A MILLER OIL COMPANY
# 4        102  Active                                         A S ENERGY
#
#       Street Address           CITY STATE     ZIP1  ZIP2       PHONE  \
# 0     3110 SCIO ROAD     CARROLLTON    OH  44615.0   NaN  3304185443
# 1      P.O. Box 4026       MARIETTA    OH  45750.0   NaN  3303830104
# 2        P O BOX 646  NEW MATAMORAS    OH  45767.0   NaN  7408653735
# 3        3490 TR 130    MILLERSBURG    OH  44654.0   NaN  3306749801
# 4  ***324 4TH AVENUE         TIFFIN    OH  44883.0   NaN  4194474832
#
#            Organization Type
# 0  Limited Liability Company
# 1  Limited Liability Company
# 2  Limited Liability Company
# 3        Sole Proprietorship
# 4                Corporation

# %%
well_owners['Status'].value_counts()
# Out:
# Status
# Active    5337
# Name: count, dtype: int64

# %% [markdown]
# Notably, all well owners with information are active. We will not have any information for inactive well companies.

# %%
well_owners.duplicated().sum()
# Out:
# 0

# %%
well_owners.to_csv('../data/final/well_owners_final.csv', index=False)

# %% [markdown]
# ### Production Analysis

# %%
# Ensure numeric columns are numeric
annual_production['Oil (Bbls)'] = pd.to_numeric(annual_production['Oil (Bbls)'], errors='coerce')
annual_production['Gas (Mcf)'] = pd.to_numeric(annual_production['Gas (Mcf)'], errors='coerce')
annual_production['Brine (Bbls)'] = pd.to_numeric(annual_production['Brine (Bbls)'], errors='coerce')

# %%
# Group by production year and sum
annual_summary = (
    annual_production
    .groupby('Production Year', as_index=False)[['Oil (Bbls)', 'Gas (Mcf)', 'Brine (Bbls)']]
    .sum()
    .sort_values('Production Year')
)

# Oil production trend
plt.figure(figsize=(10,5))
plt.plot(annual_summary['Production Year'], annual_summary['Oil (Bbls)'], marker='o')
plt.title('Total Annual Oil Production (Bbls)')
plt.xlabel('Year')
plt.ylabel('Oil (Bbls)')
plt.grid(True)
plt.show()

# Gas production trend
plt.figure(figsize=(10,5))
plt.plot(annual_summary['Production Year'], annual_summary['Gas (Mcf)'], color='orange', marker='o')
plt.title('Total Annual Gas Production (Mcf)')
plt.xlabel('Year')
plt.ylabel('Gas (Mcf)')
plt.grid(True)
plt.show()

# Brine production trend
plt.figure(figsize=(10,5))
plt.plot(annual_summary['Production Year'], annual_summary['Brine (Bbls)'], color='green', marker='o')
plt.title('Total Annual Brine Production (Bbls)')
plt.xlabel('Year')
plt.ylabel('Brine (Bbls)')
plt.grid(True)
plt.show()

# %%
# --- Top producing companies ---
top_companies = (annual_production.groupby('Owner Name')['Oil (Bbls)']
                 .sum()
                 .sort_values(ascending=False)
                 .head(10)
                 .reset_index())

plt.figure(figsize=(8,5))
sns.barplot(data=top_companies, y='Owner Name', x='Oil (Bbls)', palette='viridis')
plt.title('Top 10 Oil Producing Companies')
plt.xlabel('Oil Produced (Bbls)')
plt.ylabel('Company')
plt.show()

# %%
# --- Production by County ---
county_production = annual_production.groupby('County')[['Oil (Bbls)', 'Gas (Mcf)']].sum().sort_values('Oil (Bbls)', ascending=False)
display(county_production.head(10))
# Out:
#            Oil (Bbls)     Gas (Mcf)
# County
# GUERNSEY   42828616.0  3.528667e+08
# HARRISON   34868798.0  9.344101e+08
# CARROLL    27822320.0  9.958083e+08
# NOBLE      10958095.0  5.858540e+08
# STARK       6163073.0  6.126998e+07
# PORTAGE     3796009.0  4.422552e+07
# WAYNE       2940486.0  2.385602e+07
# MONROE      2599337.0  1.894586e+09
# COSHOCTON   2187871.0  1.764444e+07
# LICKING     2103446.0  1.386543e+07

# %% [markdown]
# ### Spatial Analysis

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Convert to GeoDataFrames
production_gdf = gpd.GeoDataFrame(
    well_info,
    geometry=gpd.points_from_xy(well_info['WELL LONGITUDE'], well_info['WELL LATITUDE']),
    crs='EPSG:4326'
)

injection_subset = permit_plug_list[permit_plug_list['PROP_WLTYPE'] == 'SW_R']
injection_gdf = gpd.GeoDataFrame(
    injection_subset,
    geometry=gpd.points_from_xy(injection_subset['WH_LONG'], injection_subset['WH_LAT']),
    crs='EPSG:4326'
)

# Reproject to Web Mercator
production_gdf = production_gdf.to_crs(epsg=3857)
injection_gdf = injection_gdf.to_crs(epsg=3857)

# %%
# Plot both datasets over a basemap
fig, ax = plt.subplots(figsize=(10, 10))
production_gdf.plot(ax=ax, color='blue', markersize=5, alpha=0.5, label='Production Wells')
injection_gdf.plot(ax=ax, color='red', markersize=30, alpha=0.7, label='Injection Wells')
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)

ax.set_title("Oil & Gas Production and Injection Wells in Ohio", fontsize=14)
ax.set_axis_off()
ax.legend()
plt.show()
